# %% [markdown]
# # Assignment

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/meghnarana/Downloads/supermarket_sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # Question
#
# As always, do your EDA, find me insights. I want a good section going over this, what you find me, i don't know. At the end, your mention some actionable items for a business, that it can do to perform better.
#
# ![](https://media.giphy.com/media/ukwPlCmJ5RmlqvQCpA/giphy.gif)
#
#
# ### Modeling
# - Fit a Simple Linear Regression Model, that tries to predict the ```Rating``` column with the help of the ```Total``` Column. We only have to use these 2 columns, nothing more.
#     - What was the training accuracy.
#     - What was the testing accuracy.
#
#
# ---
#
#
# - Make a python function, that takes ```Total``` as an input, and predicts what the ```Rating``` will be using your newly trained model to assist you !!
# - Just to be clear, your function will take 1 float value as an input and return back a float value as an output.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
sns.countplot(x='Branch', data=df)
plt.show()

sns.countplot(x='Gender', data=df)
plt.show()

sns.countplot(x='Product line', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x='Total', y='Rating', data=df)
plt.show()

sns.boxplot(x='Gender', y='Total', data=df)
plt.show()

sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/3112842913.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
sns.lineplot(x='Month', y='Total', hue='Year', data=df)
plt.show()
sns.lineplot(x='Month', y='Quantity', hue='Year', data=df)
plt.show()

# %%
sns.barplot(x='Branch', y='Total', data=df, ci=None)
plt.title('Total Sales by Branch')
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/1988054952.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Branch', y='Total', data=df, ci=None)

# %%
sns.boxplot(x='Gender', y='Total', data=df)
plt.title('Total Sales by Gender')
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
monthly_sales = df.groupby(['Year', 'Month'])['Total'].sum().reset_index()
sns.lineplot(x='Month', y='Total', hue='Year', data=monthly_sales)
plt.title('Total Sales Trend')
plt.show()

# %%
sns.histplot(df['Rating'])
plt.title('Distribution of Ratings')
plt.show()

# %%
total_revenue_by_location = df.groupby("City")["Total"].sum()
plt.bar(total_revenue_by_location.index, total_revenue_by_location.values)
plt.xlabel("Location")
plt.ylabel("Total Sales Revenue")
plt.title("Total Sales Revenue by Location")
plt.show()

# %%
grouped_df = df.groupby(['City', 'Product line']).sum()['Total']
pivot_df = grouped_df.reset_index().pivot(index='City', columns='Product line', values='Total')
pivot_df.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Total Sales Revenue by Product Type and Location')
plt.xlabel('Location')
plt.ylabel('Total Sales Revenue')
plt.legend(title='Product Type', loc='upper left')
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/3890997176.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby(['City', 'Product line']).sum()['Total']

# %%
grouped_df1 = df.groupby('Product line').sum()['Total']
percentages = grouped_df1 / grouped_df1.sum() * 100
plt.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Sales Revenue by Product Type')
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/1199553058.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df1 = df.groupby('Product line').sum()['Total']

# %%
grouped_df2 = df.groupby('City')['Total'].apply(list)
plt.boxplot(grouped_df2)
plt.title('Distribution of Sales Revenue by Location')
plt.xlabel('Location')
plt.ylabel('Sales Revenue')
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
grouped_df = df.groupby(['City', 'Date']).sum()['Total']
pivot_data = grouped_df.reset_index().pivot(index='Date', columns='City', values='Total')
pivot_data.plot(kind='area', figsize=(10,6), alpha=0.5)
plt.title('Total Sales Revenue by Location over Time')
plt.xlabel('Date')
plt.ylabel('Sales Revenue')
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/62096552.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby(['City', 'Date']).sum()['Total']

# %%
grouped_df3 = df.groupby('Product line').agg({'Total': 'sum', 'Quantity': 'sum'})

bubble_size = grouped_df3['Total'] / 1000

plt.scatter(x=grouped_df3['Total'], y=grouped_df3['Quantity'], s=bubble_size, alpha=0.5)

plt.title('Relationship between Sales Revenue, Quantity Sold, and Product Type')
plt.xlabel('Total Sales Revenue')

for i, product in enumerate(grouped_df3.index):
    plt.annotate(product, (grouped_df3['Total'][i], grouped_df3['Quantity'][i]))

plt.show()

# %%
plt.figure(figsize=(12,5))
sns.violinplot(x='Product line', y='Total', data=df)
plt.title('Distribution of Sales Revenue by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Sales Revenue')
plt.show()

# %%
grouped_data = df.groupby('Payment').sum()['Total']
grouped_data.plot(kind='bar', figsize=(8, 6))
plt.title('Total Sales Amount by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Total Sales Amount')
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/1550102832.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby('Payment').sum()['Total']

# %%
grouped_df5 = df.groupby(['Product line', 'Payment']).sum()['Total']
pivot_df5 = grouped_df5.reset_index().pivot(index='Product line', columns='Payment', values='Total')
pivot_df5.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Total Sales Amount by Product Category and Payment Method')
plt.xlabel('Product Category')
plt.ylabel('Total Sales Amount')
plt.show()
# Out:
# /var/folders/4t/l8n2nzbd05d3fq8nmdrc7hv40000gn/T/ipykernel_7034/2417456578.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df5 = df.groupby(['Product line', 'Payment']).sum()['Total']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X = df['Total']
Y = df['Rating']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (800,)
# Y_train shape: (800,)
# X_test shape: (200,)
# Y_test shape: (200,)

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
def predict_rating(total):
    # Predict the Rating based on the Total sales amount
    rating_pred = model.predict([[total]])
    return rating_pred[0]

# %%
predicted_rating = predict_rating(5000)
print(predicted_rating)
# Out:
# 5.437804290829797

# %%
train_accuracy = model.score(X_train, Y_train)
test_accuracy = model.score(X_test, Y_test)

# %%
train_accuracy
# Out:
# 0.002238503883519427

# %%
test_accuracy
# Out:
# -0.006129474889873032
